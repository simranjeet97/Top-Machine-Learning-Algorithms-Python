# %% [markdown]
# #**Top Machine Learning Algorithms**
#
# **“Machine learning will increase productivity throughout the supply chain.”** ~Dave Waters
#
# <img src="https://drive.google.com/uc?export=view&id=1q2XdeHUW8Y7Z7WN9VdGfRaQcewnroWoq" alt ="Linear Regression" width="500"/>

# %% [markdown]
# ##**List of Machine Learning Algorithms**
#
# 1. Regression Algorithms
# 2. Decision Tree
# 3. SVM
# 4. Naive Bayes
# 5. kNN
# 6. K-Means
# 7. Random Forest
# 8. Dimensionality Reduction Algorithms
# 9. Gradient Boosting algorithms

# %% [markdown]
# ##**Machine Learning ?**
# ML is an **Logical Approach to mimic the human abilities** to understand or learn automatically. It's an **application of AI** that Learn with experience without human intervention. This can be done mainly using **Data** from which the System learns.
#
# ### **Types of Machine Learning** -
# 1. **Supervised Learning** - It states that System learns from Labeled Data.All Algorithms comes under Supervisde Learning consist of a Target/Dependent Variable which is going to be predicted from all other Independent Variables.
# We keep traning our data until it reach a certain Accuracy point or Accuracy Level.
# *Examples*: Regression, Decision Tree, Random Forest, KNN, Logistic Regression etc.
#
# 2. **Un-Supervised Learning** - It states that System learn by identifying the Pattern between the data or using Unlabeled Data, because we do not have any Target Variable, We Categorize the Data in different Segments and Clusters based on various features.
# *Examples*: Apriori algorithm, K-means.
#
# 3. **Reinforcement Learning** - These algorithms specifically based on better decision makings. These algorithms works based on the Experience they are facing or environment in which they are applied and continually takes Hit and Trail decisions or Reward and Punishment system. Using past decision it keep improving and make decision making more accurate.
# *Examples*: Markov Decision Process

# %% [markdown]
# #**1. Regression Algorithms**
# Regression Algorithms are used to explain the Relationship between the Set of Independent Variables and the Dependent Variable. Regression Analysis works on an Equation where the Coefficients shows the relationship between the Independent and the Dependent Variable. That Euquation can also be used for Prediction.
#
# **Use Cases** -
# 1. Multiple Independent Variables and One Target Variable
# 2. Continuous and Categorical variables
# 3. In Polynomial terms to model curvature
# 4. Assess interaction terms to determine whether the effect of one independent variable depends on the value of another variable

# %% [markdown]
# ## 1. **Linear Regression**
# It is the simplest algorithms of machine learning, as its main focus is to determine the relationship between the Independent Variables(one or more then one) and Target Variable (Dependent Variable).
#
# When there is only One Independent Variable it is called **Uni-Variate Linear Regression** and if there are multiple Independent Variables it is called **Multiple Linear Regression.**
#
#
# <img src="https://miro.medium.com/max/1280/1*LEmBCYAttxS6uI6rEyPLMQ.png" alt ="Linear Regression" width="500"/>
#
# **Mathematical Foundation** -
#
# Let's say the Target Variable is 'Y' and set of all the Independent Variables are 'X = (X1,X2,....Xn)', Here 'n' is the number of Predictors.
# So the Equation of Linear Relationship between X and Y is -
#
#     Y = B0 + B1X1 + B2X2 + .... + BnXn + Error
#
# 'B' is the Regression Coefficients.
#
# So, Here Linera Regression estimates the Regression Coefficients (B0,B1..Bn). The Function should be Written as F(X) = B0 + B1X1 + B2X2 + .... + BnXn, that determines the Dependencies between the input and output variables.
#
# So, Now the Predicted Response  F(Xk), for each observation k = 1....n is very similar to the Actual Value of Yk.
#
# The Difference between the Yk - F(Xk) for all the Observations called Error or Residual.
#
# Regression Analysis is basically all about predicting Weights, that has smallest Residuals.
#
# We use Method of Ordinary Least Squares for best Weights, by minimizing the sum of Sqaured Residuals for all the Observations k = 1....n.
#
#     OLS =  Σᵢ(𝑦ᵢ - 𝑓(𝐱ᵢ))²
#
# The variation of actual responses Yk, k = 1…𝑛, occurs partly due to the dependence on the predictors Xk.
#
# **Coefficient of Determination (𝑅²)** - It states the amount of variation in 'Y' can be explained by the dependence on 'X' using the particular regression model.
#
# Larger 𝑅² indicates a better fit and means that the model can better explain the variation of the output with different inputs.
#
# The value 𝑅² = 1 corresponds to OLS = 0, that is to the perfect fit since the values of predicted and actual responses fit completely to each other.
# [1](https://realpython.com/linear-regression-in-python/)

# %% [markdown]
# ## **a. Simple or Uni-Variate Linear Regression**
# When there is only One Independent Variable it is called **Uni-Variate Linear Regression**, where Y = x
#
# <img src="https://files.realpython.com/media/fig-lin-reg.a506035b654a.png" alt ="Linear Regression" width="800"/>
#
# #### **Implementation Explaination** -
#
# So, When we have input and output (x,y pairs -- green circles). These are Real Values or Observations k.
#
# Our objective is to Cacluate the optimal values of the predicted weights (B0 and B1) in the Estimated Regression Function that Draws the Black Line having Equation 𝑓(𝑥) = 𝑏₀ + 𝑏₁𝑥,, this calculation can minimize the OLS and we get the perfect Estimated Regression function.
#
# Linear Equation of a Line, Y = mk + c, So, compare our Equation with the Equation of Line, We got **B0 is Intercept** that shows the point where our Estimated Regression Function's Black line Crosses the Y-Axis, and here we have f(x) = 0 for x.
#
# **B1 is the Slope of Line**
#
# So, using our Observations k, in the Equation of Line we for our Predicted Responses (Red Squares), for Example if input k=5 the function predicted f(5) = 6.32.
#
# The Residuals and Error is Gray Dashed Lines distance between the red squares and green circles, can be calculated as Yk - f(Xk) for all the k = 1,....,n.
#
# So our main goal is to minimize these Error to make the red squares and green cirles close enough so that our line is perfect for prediction.
#
#
# **NOTE** - The p-values help determine whether the relationships that you observe in your sample also exist in the larger population. The p-value for each independent variable tests the null hypothesis that the variable has no correlation with the dependent variable.
#
#     A p-value less than 0.05 (typically ≤ 0.05) is statistically significant.It indicates strong evidence against the null hypothesis,than a 5% probability the null is correct (and the results are random). Therefore, we reject the null hypothesis, and accept the alternative hypothesis.
#     A p-value higher than 0.05 (> 0.05) is not statistically significant and indicates strong evidence for the null hypothesis.

# %%
#From Scratch Implementation 

import numpy as np
import matplotlib.pyplot as plt
 
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
 
    return (b_0, b_1)
 
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
    plt.scatter(x, y_pred,color = "r")
 
    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')
 
    # function to show plot
    plt.show()
 
def main():
    # observations / data
    x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
    y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
 
    # estimating coefficients
    b = estimate_coef(x, y)
    print("Estimated coefficients:\nb_0 = {}  \
          \nb_1 = {}".format(b[0], b[1]))
 
    # plotting regression line
    plot_regression_line(x, y, b)
 
if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b_0 = 103.10596026490065
# b_1 = -1.75128771155261

# %%
#Library Implementations 

import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

print("Predicted Values -", mymodel)
print("Coefficient of Determination -",r)
print("P-Value -",p)
print("Error -",std_err)
print("Slope of Line -",slope)
print("Intercept -",intercept)

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# Predicted Values - [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]
# Coefficient of Determination - -0.758591524376155
# P-Value - 0.0026468739224561064
# Error - 0.453536157607742
# Slope of Line - -1.7512877115526118
# Intercept - 103.10596026490066

# %%
#Prediction 
pred = myfunc(12)
print(pred)
# Out:
# 82.09050772626932

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])
print(x)
print(y)
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('Coefficient of Determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')

y_pred = model.intercept_ + model.coef_ * x
print('predicted response:', y_pred, sep='\n')
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [ 5 20 14 32 22 38]
# Coefficient of Determination: 0.7158756137479542
# intercept: 5.633333333333329
# slope: [0.54]
# predicted response:
# [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]
# predicted response:
# [[ 8.33333333]
#  [13.73333333]
#  [19.13333333]
#  [24.53333333]
#  [29.93333333]
#  [35.33333333]]

# %% [markdown]
# ## 2. **Multi-Linear Regression**
# This type of Regression is just updated version of Linear Regression in where there are More then one Independent Variables.
#
# Equation becomes -
#
#     f(x1,x2,...,xn) = b0 + b1x1 + b2x2 + ... bnxn + Error (n+1 weights to be determined)

# %%
from sklearn.linear_model import LinearRegression

x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35]]
y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.8615939258756776
# intercept: 5.52257927519819
# slope: [0.44706965 0.25502548]

# %%
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]

# %% [markdown]
# ## **3. Polynomial Regression**
#
# Polynomial Regression is another type of Linear Regression that include Linear Terms like 𝑏₁𝑥₁ along with non-linear terms  like 𝑏₂𝑥₁², 𝑏₃𝑥₁³, or even 𝑏₄𝑥₁𝑥₂, 𝑏₅𝑥₁²𝑥₂, and so on in your Regression function 𝑓.
#
# For Example - Degree 2 Estimated Polynomial Regression Function -
#
#     𝑓(𝑥) = 𝑏₀ + 𝑏₁𝑥 + 𝑏₂𝑥².
#
# Same here, we need to calculate the 𝑏₀, 𝑏₁, and 𝑏₂, which minimize the OLS.
#
# Let's Compare the Previous Degree-1 Regression Function with the
#
#     𝑓(𝑥₁, 𝑥₂) = 𝑏₀ + 𝑏₁𝑥₁ + 𝑏₂𝑥₂
#     𝑓(𝑥₁) = 𝑏₀ + 𝑏₁𝑥₁
#
# linear regression Function. So, They are quite similar with only some values need to be find out those 𝑏₀, 𝑏₁, and 𝑏₂. So, Solution is to solve the Polynomial Regression Problem just like the Linear Regression Problem usng 𝑥² as input variable.
#
# In case of 2nd-Degree Polynomial means there are two variables, the regression function looks like this -
#
#     𝑓(𝑥₁, 𝑥₂) = 𝑏₀ + 𝑏₁𝑥₁ + 𝑏₂𝑥₂ + 𝑏₃𝑥₁² + 𝑏₄𝑥₁𝑥₂ + 𝑏₅𝑥₂².
#
# So the Procedure is same as the Linear Equation we just need to apply that one the five inputs - 𝑥₁, 𝑥₂, 𝑥₁², 𝑥₁𝑥₂, and 𝑥₂²
#
# The Result that we get is the values of the weights - 𝑏₀, 𝑏₁, 𝑏₂, 𝑏₃, 𝑏₄, and 𝑏₅. That decide the OLS.

# %% [markdown]
# ###**UNDERFITTING AND OVERFITTING** -
#
# This occurs when we are confuse to decide the optimal degree of the polynomial regression.
#
# **Underfitting** occurs when a model can’t accurately capture the dependencies among data, usually as a consequence of its own simplicity. It often yields a low 𝑅² with known data and bad generalization capabilities when applied with new data.
#
# **Overfitting** happens when a model learns both dependencies among data and random fluctuations. In other words, a model learns the existing data too well. Complex models, which have many features or terms, are often prone to overfitting. When applied to known data, such models usually yield high 𝑅². However, they often don’t generalize well and have significantly lower 𝑅² when used with new data.
# [1](https://realpython.com/linear-regression-in-python/)
#
#
#
# <img src="https://files.realpython.com/media/poly-reg.5790f47603d8.png" alt ="Linear Regression" width="800"/>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([15, 11, 2, 8, 25, 32])
print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [15 11  2  8 25 32]

# %%
transformer = PolynomialFeatures(degree=2, include_bias=False)

# %%
transformer.fit(x)
# Out:
# PolynomialFeatures(degree=2, include_bias=False, interaction_only=False,
#                    order='C')

# %%
x_sqr = transformer.transform(x)

# %%
print(x_sqr)
# Out:
# [[   5.   25.]
#  [  15.  225.]
#  [  25.  625.]
#  [  35. 1225.]
#  [  45. 2025.]
#  [  55. 3025.]]

# %%
model = LinearRegression().fit(x_sqr, y)

# %%
r_sq = model.score(x_sqr, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.7178963893249607
# intercept: 4.438392857142851
# coefficients: [ 0.65785714 -0.00196429]

# %%
#IF WE INCLUDE BIASNESS
x_sqr = PolynomialFeatures(degree=2, include_bias=True).fit_transform(x)

# %%
print(x_sqr)
# Out:
# [[1.000e+00 5.000e+00 2.500e+01]
#  [1.000e+00 1.500e+01 2.250e+02]
#  [1.000e+00 2.500e+01 6.250e+02]
#  [1.000e+00 3.500e+01 1.225e+03]
#  [1.000e+00 4.500e+01 2.025e+03]
#  [1.000e+00 5.500e+01 3.025e+03]]

# %%
model = LinearRegression(fit_intercept=False).fit(x_sqr, y)

# %%
r_sq = model.score(x_sqr, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.7178963893249607
# intercept: 0.0
# coefficients: [ 4.43839286e+00  6.57857143e-01 -1.96428571e-03]

# %%
y_pred = model.predict(x_sqr)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 7.67857143 13.86428571 19.65714286 25.05714286 30.06428571 34.67857143]

# %%
#For Multiple Features
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Step 2a: Provide data
x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35]]
y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)

# Step 2b: Transform input data
x_ = PolynomialFeatures(degree=2, include_bias=False).fit_transform(x)

# Step 3: Create a model and fit it
model = LinearRegression().fit(x_, y)

# Step 4: Get results
r_sq = model.score(x_, y)
intercept, coefficients = model.intercept_, model.coef_

# Step 5: Predict
y_pred = model.predict(x_)
print(y_pred)
# Out:
# [ 0.54047408 11.36340283 16.07809622 15.79139    29.73858619 23.50834636
#  39.05631386 41.92339046]

# %%
r_sq = model.score(x_, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.9453701449127822
# intercept: 0.843055645239577
# coefficients: [ 2.44828275  0.16160353 -0.15259677  0.47928683 -0.4641851 ]

# %% [markdown]
# ###**STATSMODEL LIBRARY**
# The Advance Statistical Model Library with All Paramteres

# %%
import numpy as np
import statsmodels.api as sm
x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35]]
y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)
#One's column to inputs to calculate intercept
x = sm.add_constant(x)
print(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [[ 1.  0.  1.]
#  [ 1.  5.  1.]
#  [ 1. 15.  2.]
#  [ 1. 25.  5.]
#  [ 1. 35. 11.]
#  [ 1. 45. 15.]
#  [ 1. 55. 34.]
#  [ 1. 60. 35.]]

# %%
print(y)
# Out:
# [ 4  5 20 14 32 22 38 43]

# %%
#OLS - ordinary least squares of Regression
model = sm.OLS(y, x)

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     15.56
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):            0.00713
# Time:                        17:58:25   Log-Likelihood:                -24.316
# No. Observations:                   8   AIC:                             54.63
# Df Residuals:                       5   BIC:                             54.87
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5226      4.431      1.246      0.268      -5.867      16.912
# ...

# %%
print('predicted response:', results.fittedvalues, sep='\n')
# Out:
# predicted response:
# [ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]

# %%
print('predicted response:', results.predict(x), sep='\n')
# Out:
# predicted response:
# [ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]

# %%
x_new = sm.add_constant(np.arange(10).reshape((-1, 2)))
y_new = results.predict(x_new)
print(y_new)
# Out:
# [ 5.77760476  7.18179502  8.58598528  9.99017554 11.3943658 ]

# %% [markdown]
# ## **Decision Tree Algorithms**
# Decision Tree Algorithms are Supervised Learning Algorithms that are used for Classification and Regression Cases. It works for both Categorical and Continous Data.
#
# Tree based algorithms empower predictive models with high accuracy, stability and ease of interpretation. Unlike linear models, they map non-linear relationships quite well.
#
# In this technique, we split the population or sample into two or more homogeneous sets (or sub-populations) based on most significant splitter / differentiator in input variables.
#
# <img src="https://d1jnx9ba8s6j9r.cloudfront.net/blog/wp-content/uploads/2018/12/Decision-Tree-Machine-Learning-Algorithms-Edureka.png" alt ="Linear Regression" width="800"/>
#
# ### **Working**
# 1. Select the best attribute using Attribute Selection Measures(ASM) to split the records.
# 2. Make that attribute a decision node and breaks the dataset into smaller subsets.
# 3. Starts tree building by repeating this process recursively for each child until one of the condition will match:
#   1. All the tuples belong to the same attribute value.
#   2. There are no more remaining attributes.
#   3. There are no more instances.
#
# <img src="https://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1545934190/2_btay8n.png" alt ="Linear Regression" width="800"/>
#
#
# ### **Types of Decision Trees** -
#
# On the basis of the type of target variable we have. It can be of two types:
#
# **1. Categorical Variable Decision Tree**: Decision Tree which has categorical target variable (Yes or No, True or False) then it called as categorical variable decision tree.
#
# **Example:**- In above scenario of We play or not problem, where the target variables is "PLAY" or "DON'T PLAY".
#
# **2. Continuous Variable Decision Tree**: Decision Tree has continuous target variable( Numbers ) then it is called as Continuous Variable Decision Tree.
#
# **Example:**- Let’s say we have a problem to predict whether a customer will pay his renewal premium with an insurance company (yes/ no). Here we know that income of customer is a significant variable but insurance company does not have income details for all customers. Now, as we know this is an important variable, then we can build a decision tree to predict customer income based on occupation, product and various other variables. In this case, we are predicting values for continuous variable.
#
# ### **Terminologies in Decision Tree Algorithhms**
#
# **1. Root Node:** It represents entire population or sample and this further gets divided into two or more homogeneous sets.
#
# **2. Splitting:** It is a process of dividing a node into two or more sub-nodes.
#
# **3. Decision Node:** When a sub-node splits into further sub-nodes, then it is called decision node.
#
# **4. Leaf/ Terminal Node:** Nodes do not split is called Leaf or Terminal node.
#
# **5. Pruning:** When we remove sub-nodes of a decision node, this process is called pruning. You can say opposite process of splitting.
#
# **6. Branch / Sub-Tree:** A sub section of entire tree is called branch or sub-tree.
#
# **7. Parent and Child Node:** A node, which is divided into sub-nodes is called parent node of sub-nodes where as sub-nodes are the child of parent node.
#
# <img src="https://miro.medium.com/max/688/1*bcLAJfWN2GpVQNTVOCrrvw.png" alt ="Linear Regression" width="600"/>
#
# ### **Advantages** -
# 1. Easy to Understand
# 2. Useful for Data Exploration
# 3. Less Data Cleaning Required as It is not influenced by outliers and missing values to a fair degree.
# 4. Data Type is not a Constraint as It can handle both numerical and categorical variables.
# 5. Non-Parametric Method
#
# ### **Disavantages** -
# 1. Overfitting
# 2. Not good fit for Continous Variables

# %% [markdown]
# ## **Regression Trees vs Classification Trees** (CART)
# As we know that Terminal Nodes are lies at bottom of the decision Tree. This means decision trees are typically draws from bottom to up as bottom part contains the leaves and upper part the Roots.
#
# <img src="https://pbs.twimg.com/media/EqHqCVYXMAMigLZ.jpg" alt ="Linear Regression" width="300"/>
#
# Both Regression and Classification Trees are similar so the Similarities and Differeneces between them are here -
#
# <img src="https://drive.google.com/uc?export=view&id=18ldxq1yIvWElf-rsC41csElMl34YPmoD" alt ="Linear Regression" width="500"/>
#
# ## **How Tree Based Algorithm Decide from Where to Split**
# Split part in Tree based algorithms heavily affects the accuracy but the decision criteria is different for both Regression and Classfication Trees.
# It uses multiple algorithms (on the basis of Target Variable) to decide from where to split a node into two or more sub-nodes and creation of more sub-nodes increases the homogeneity of the sub-nodes. Decision tree splits the nodes on all available variables and then selects most homogeneous sub-nodes to split. Purity of the node increases with respect to the target variable.
#
# **Algorithms used in Decision Tree are -**
# 1. Gini
# 2. Chi-Square
# 3. Information Gain
# 4. Reduction in Variance
#
# <img src="https://www.inbenta.com/wp-content/uploads/2017/10/Webp.net-resizeimage-9.jpg" alt ="Linear Regression" width="800"/>
#
#
# ### **Key-Parameters of Tree Based Algorithms and Ways to Avoid Over-Fitting**
# Overfitting can be prevented by using these two ways -
# **1. Setting Constraints on Tree Size**
# We can define the Tree by using the Various Parameters and also it is a greedy approach means it will check for best split fast and move forward until one of the certain condition is reached to stop it, for example -
# <img src="https://www.analyticsvidhya.com/wp-content/uploads/2016/02/tree-infographic-1024x429.png" alt ="Linear Regression" width="800"/>
#
# Parameters are -
# 1. Minimum samples for a node spli
# 2. Minimum samples for a terminal node (leaf)
# 3. Maximum depth of tree (vertical depth)
# 4. Maximum number of terminal nodes
# 5. Maximum features to consider for split
#
# **2. Tree Pruning**
# Pruning is not greedy as much as of the Setting Constraints as it takes more choices and choose wisely.
# So here is just a sample to implement pruning in Tree is -
# 1. Make Decision Tree to Large Depth.
# 2. Then Start with bottom and Remove the leaves which Gives the negative returns comapred with Top.
# 3. Let's Say we got loss of 10 (-10) and then next split gives us gain of 20(+20), in First method tree will stop at first step but in pruning it goes further and get the +10 (20-10) gain and keep both the leaves.
#
# **Use xgboost to implement tree pruning**

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
#Feature Selection
#split dataset in features and target variable
feature_cols = ['Pregnancies', 'Insulin', 'BMI', 'Age','Glucose','BloodPressure','DiabetesPedigreeFunction']
X = df[feature_cols] # Features
y = df.Outcome # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7012987012987013

# %%
#Visualization
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
#Improving the Model
#Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7705627705627706

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
#This pruned model is less complex, explainable, and easy to understand than the previous decision tree model plot.

# %% [markdown]
# ## **Logistic Regression**
# When data scientists may come across a new classification problem, the first algorithm that may come across their mind is Logistic Regression. It is a supervised learning classification algorithm which is used to predict observations to a discrete set of classes. Practically, it is used to classify observations into different categories. Hence, its output is discrete in nature. Logistic Regression is also called Logit Regression. It is one of the most simple, straightforward and versatile classification algorithms which is used to solve classification problems.
#
# In statistics, the Logistic Regression model is a widely used statistical model which is primarily used for classification purposes. It means that given a set of observations, Logistic Regression algorithm helps us to classify these observations into two or more discrete classes. So, the target variable is discrete in nature.
#
# The Logistic Regression algorithm works as follows -
#
# Logistic Regression algorithm works by implementing a linear equation with independent or explanatory variables to predict a response value. For example, we consider the example of number of hours studied and probability of passing the exam. Here, number of hours studied is the explanatory variable and it is denoted by x1. Probability of passing the exam is the response or target variable and it is denoted by z.
#
# If we have one explanatory variable (x1) and one response variable (z), then the linear equation would be given mathematically with the following equation-
#
#     z = β0 + β1x1
#
# Here, the coefficients β0 and β1 are the parameters of the model.
#
# If there are multiple explanatory variables, then the above equation can be extended to -
#
#     z = β0 + β1x1+ β2x2+……..+ βnxn
#
# Here, the coefficients β0, β1, β2 and βn are the parameters of the model.
#
# So, the predicted response value is given by the above equations and is denoted by z.
#
# ## **Sigmoid Function**
# This predicted response value, denoted by z is then converted into a probability value that lie between 0 and 1. We use the sigmoid function in order to map predicted values to probability values. This sigmoid function then maps any real value into a probability value between 0 and 1.
#
# In machine learning, sigmoid function is used to map predictions to probabilities. The sigmoid function has an S shaped curve. It is also called sigmoid curve.
#
# A Sigmoid function is a special case of the Logistic function. It is given by the following mathematical formula.
#
# Graphically, we can represent sigmoid function with the following graph.
#
# <img src = "https://miro.medium.com/max/970/1*Xu7B5y9gp0iL5ooBj7LtWw.png">
#
# ## **Decision boundary**
# The sigmoid function returns a probability value between 0 and 1. This probability value is then mapped to a discrete class which is either “0” or “1”. In order to map this probability value to a discrete class (pass/fail, yes/no, true/false), we select a threshold value. This threshold value is called Decision boundary. Above this threshold value, we will map the probability values into class 1 and below which we will map values into class 0.
#
# Mathematically, it can be expressed as follows:-
#
#     p ≥ 0.5 => class = 1
#
#     p < 0.5 => class = 0
#
# Generally, the decision boundary is set to 0.5. So, if the probability value is 0.8 (> 0.5), we will map this observation to class 1. Similarly, if the probability value is 0.2 (< 0.5), we will map this observation to class 0. This is represented in the graph below-
#
# <img src = "https://ml-cheatsheet.readthedocs.io/en/latest/_images/logistic_regression_sigmoid_w_threshold.png">
#
# ## **Assumptions of Logistic Regression**
#
# The Logistic Regression model requires several key assumptions. These are as follows:-
#
# 1. Logistic Regression model requires the dependent variable to be binary, multinomial or ordinal in nature.
#
# 2. It requires the observations to be independent of each other. So, the observations should not come from repeated measurements.
#
# 3. Logistic Regression algorithm requires little or no multicollinearity among the independent variables. It means that the independent variables should not be too highly correlated with each other.
#
# 4. Logistic Regression model assumes linearity of independent variables and log odds.
#
# 5. The success of Logistic Regression model depends on the sample sizes. Typically, it requires a large sample size to achieve the high accuracy.
#
# ## **Types of Logistic Regression**
#
# 1. **Binary Logistic Regression**
# In Binary Logistic Regression, the target variable has two possible categories. The common examples of categories are yes or no, good or bad, true or false, spam or no spam and pass or fail.
#
# 2. **Multinomial Logistic Regression**
# In Multinomial Logistic Regression, the target variable has three or more categories which are not in any particular order. So, there are three or more nominal categories. The examples include the type of categories of fruits - apple, mango, orange and banana.
#
# 3. **Ordinal Logistic Regression**
# In Ordinal Logistic Regression, the target variable has three or more ordinal categories. So, there is intrinsic order involved with the categories. For example, the student performance can be categorized as poor, average, good and excellent.
#
#
#
# <img src="https://miro.medium.com/max/546/1*MvRRHq-vkJX5rbr4y-a34Q.png" height="60px" width="500px">

# %% [markdown]
# ## **Confusion Matrix**
# A confusion matrix is a table that is often used to describe the performance of a classification model (or “classifier”) on a set of test data for which the true values are known.Let us look at some of the important terms of confusion matrix.
#
# Confusion matrix whether employees will leave a company or not
#
# <img src="https://miro.medium.com/max/386/1*GMlSubndVt3g7FmeQjpeMA.png">
#
# For More Information - Read [Confusion Matrix - Full Explained](https://www.linkedin.com/pulse/classification-confusion-matrix-explained-simranjeet-singh/?trackingId=5480LZDMTvy9vQRub70qOA%3D%3D)

# %% [markdown]
# ## **Binary Logistic Regression Project**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("train.csv")
print('Training data shape: ', data.shape)
data.head()
# Out:
# Training data shape:  (891, 12)
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test_data = pd.read_csv("test.csv")
print('Testing data shape: ', test_data.shape)
test_data.head()
# Out:
# Testing data shape:  (418, 11)
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
print(data.describe())
print(data.info())
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#Count of Who Survived or Who not from the data
sns.countplot(x = 'Survived',data = data)

# %%
#Plot Which Sex - Male and Female should be alive or Dead
sns.countplot(x = 'Survived',hue = 'Sex',data = data)

# %%
# Which class should alive and dead has most peoples
sns.countplot(x = 'Survived',hue = 'Pclass',data = data)

# %%
sns.boxplot(x='Pclass',y='Age',data=data)

# %%
# Verifying Null and NAN Values
print(data.isnull().sum())
print("------------------")
print(test_data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ------------------
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
nameOne= data['Name'][38]
print(nameOne)
# Out:
# Vander Planke, Miss. Augusta Maria

# %%
nameOne.split(',')[1].split('.')[0]
# Out:
# ' Miss'

# %%
# Handling Missing Values of Age we should be do this on Name basis, becuase only using mean we cannot assign a kid a age of 29 or 30.
data['Initial'] = data['Name'].apply(lambda x : x.split(',')[1].split('.')[0].strip())
test_data['Initial'] = test_data['Name'].apply(lambda x : x.split(',')[1].split('.')[0].strip())

# %%
old = ['Mlle','Mme', 'Ms', 'Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona']
new = ['Miss','Miss','Miss','Mr','Mr',  'Mrs',  'Mrs',  'Other',  'Other','Other','Mr','Mr','Mr','Other']
data['Initial'] = data['Initial'].replace(old,new)
test_data['Initial'] = test_data['Initial'].replace(old,new)

# %%
print(test_data['Initial'].unique())
data['Initial'].unique()
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Other']
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
def add_age(cols):
    Age = cols[0]
    initial = cols[1]
    if pd.isnull(Age):
        return int(data[data["Initial"] == initial]["Age"].mean())
    else:
        return Age

# %%
data['Age'] = data[['Age','Initial']].apply(add_age,axis=1)
test_data['Age'] = test_data[['Age','Initial']].apply(add_age,axis=1)

# %%
data.drop("Cabin",inplace=True,axis=1)
test_data.drop("Cabin",inplace=True,axis=1)

# %%
data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)
test_data['Embarked'].fillna(test_data['Embarked'].mode()[0],inplace=True)

# %%
test_data['Fare'].fillna(test_data['Fare'].mean(),inplace=True)

# %%
data['Family'] = data['SibSp'] + data['Parch']
test_data['Family'] = test_data['SibSp'] + test_data['Parch']

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked Initial  Family
# 0            1         0       3  ...        S      Mr       1
# 1            2         1       1  ...        C     Mrs       1
# 2            3         1       3  ...        S    Miss       0
# 3            4         1       1  ...        S     Mrs       1
# 4            5         0       3  ...        S      Mr       0
#
# [5 rows x 13 columns]

# %%
def process_age(df,cut_points,label_names):
    df["Age"] = df["Age"].fillna(-0.5)
    df["Age_categories"] = pd.cut(df["Age"],cut_points,labels=label_names)
    return df

# %%
cut_points = [-1,0,5,12,18,35,60,100]
label_names = ["Missing","Infant","Child","Teenager","Young Adult","Adult","Senior"]
train = process_age(data,cut_points,label_names)
test = process_age(test_data,cut_points,label_names)

pivot = train.pivot_table(index="Age_categories",values='Survived')
pivot.plot.bar()

# %%
def create_dummies(df,column_name):
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    return df

for column in ["Pclass","Sex","Age_categories",'Embarked']:
    train = create_dummies(train,column)
    test = create_dummies(test,column)

# %%
train.drop(['Name','Sex','Ticket','Pclass','Age_categories','Embarked'],inplace=True,axis=1)
test.drop(['Name','Sex','Ticket','Pclass','Age_categories','Embarked'],inplace=True,axis=1)

# %%
model = LogisticRegression()
columns = ['PassengerId', 'Age', 'Fare','Family',
       'Pclass_1', 'Pclass_2', 'Pclass_3', 'Sex_female', 'Sex_male',
       'Age_categories_Missing', 'Age_categories_Infant',
       'Age_categories_Child', 'Age_categories_Teenager',
       'Age_categories_Young Adult', 'Age_categories_Adult',
       'Age_categories_Senior']

# %%
model.fit(train[columns], train["Survived"])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# ValidationSet
X = train[columns]
y = train['Survived']

train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.20,random_state=0)

# %%
# Making predictions and measuring accuracy
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(val_X)
accuracy = accuracy_score(val_y, predictions)
print(accuracy)
from sklearn.metrics import classification_report
print(classification_report(val_y,predictions))
# Out:
# 0.8044692737430168
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       110
#            1       0.78      0.68      0.73        69
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
# Using cross validation for more robust error measurement
lr = LogisticRegression()
scores = cross_val_score(lr, X, y, cv=10)
scores.sort()
accuracy = scores.mean()

print(scores)
print(accuracy)
# Out:
# [0.7752809  0.7752809  0.79775281 0.79775281 0.79775281 0.80898876
#  0.82022472 0.82222222 0.83146067 0.85393258]
# 0.8080649188514357

# %%
lr = LogisticRegression()
lr.fit(X,y)
predictions_test = lr.predict(test[columns])

# %%
predData = test[['Age','Initial','PassengerId']]

# %%
predData['Predictions'] = predictions_test

# %%
predData[:]
# Out:
#       Age Initial  PassengerId  Predictions
# 0    34.5      Mr          892            0
# 1    47.0     Mrs          893            0
# 2    62.0      Mr          894            0
# 3    27.0      Mr          895            0
# 4    22.0     Mrs          896            1
# ..    ...     ...          ...          ...
# 413  32.0      Mr         1305            0
# 414  39.0   Other         1306            1
# 415  38.5      Mr         1307            0
# 416  32.0      Mr         1308            0
# 417   4.0  Master         1309            0
#
# [418 rows x 4 columns]

# %% [markdown]
# # **Multi-Class Logistic Regression**
# You can think of multinomial logistic regression as logistic regression (more specifically, binary logistic regression) on steroids. While the binary logistic regression can predict binary outcomes (eg.- yes or no, spam or not spam, 0 or 1, etc.), the MLR can predict one out of k-possible outcomes, where k can be any arbitrary positive integer.
#
# <img src="https://miro.medium.com/max/770/1*dVsfG6i-Y93prmLgTcxRwA.jpeg">
#
# ## **How does MLR work?**
# The multinomial regression function is a statistical classification algorithm. What this means is that once we feed the function a set of features, the model performs a series of mathematical operations to normalize the input values into a vector of values that follows a probability distribution.
#
# <img src="https://miro.medium.com/max/770/1*23H-Vwy_p43ai0Qvz9d6Pg.jpeg">
#
# - The input that we give to the model is a feature vector, X, containing features x1, x2, x3…..xn.
# - The output we get is a probability vector Y, containing probabilities y1, y2, y3…yk for the k target classes.
# - Here, y1 + y2 + y3… + yk = 1, since the total probability of all the possible events in a system is always 1.
#
# Finally, the outcome with the highest probability will be the predicted outcome for the given feature set.
# **Now the question is, how exactly does the MLR function convert feature sets to probability values?** We will try to understand this while working on our project.
#
# ## **Formulating the Model from Scratch**
# MLR model takes a vector of features as the input and then, on the basis of the features, computes the probabilities for the possible outcomes. So how exactly does the MLR model does that? Let us find out in this section where we will code an MLR model.
# The multinomial regression function consists of two functional layers-
# - Linear prediction function (a.k.a. logit layer)
# - Softmax function (a.k.a. softmax layer)
#
# First, let us see what the linear predictor function does. Given below is the formula for the linear prediction function.
#
# <img src = "https://miro.medium.com/max/2602/1*-sM-0yXmTTbBNZ0cF0rbaA.jpeg">
#
# <img src = "https://miro.medium.com/max/2000/1*iw6tUEi05dAtlJNZl4anbQ.jpeg">
#
# **Example-** A biologist may be interested in food choices that alligators make. Adult alligators might have different preferences from young ones. The outcome variable here will be the types of food, and the predictor variables might be size of the alligators and other environmental variables.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

np.random.seed(42)

train = pd.read_csv('train.csv')
#print(train['species'])
print("Total Unique Species - ", train['species'].nunique())
train.head()
# Out:
# Total Unique Species -  99
#    id                species   margin1  ...  texture62  texture63  texture64
# 0   1            Acer_Opalus  0.007812  ...   0.004883   0.000000   0.025391
# 1   2  Pterocarya_Stenoptera  0.005859  ...   0.000977   0.039062   0.022461
# 2   3   Quercus_Hartwissiana  0.005859  ...   0.000000   0.020508   0.002930
# 3   5        Tilia_Tomentosa  0.000000  ...   0.017578   0.000000   0.047852
# 4   6     Quercus_Variabilis  0.005859  ...   0.000000   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
x_train = train.drop(['id', 'species'], axis=1).values
x_train
# Out:
# array([[0.007812, 0.023438, 0.023438, ..., 0.004883, 0.      , 0.025391],
#        [0.005859, 0.      , 0.03125 , ..., 0.000977, 0.039062, 0.022461],
#        [0.005859, 0.009766, 0.019531, ..., 0.      , 0.020508, 0.00293 ],
#        ...,
#        [0.001953, 0.003906, 0.      , ..., 0.027344, 0.      , 0.001953],
#        [0.      , 0.      , 0.046875, ..., 0.      , 0.001953, 0.00293 ],
#        [0.023438, 0.019531, 0.03125 , ..., 0.023438, 0.025391, 0.022461]])

# %%
le = LabelEncoder().fit(train['species'])
y_train = le.transform(train['species'])

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)

# %%
params = {'C':[100, 1000], 'tol': [0.001, 0.0001]}

# %%
log_reg = LogisticRegression(solver='lbfgs', multi_class='multinomial')
clf = GridSearchCV(log_reg, params, scoring='accuracy', refit='True', n_jobs=-1, cv=5)
clf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100,
#                                           multi_class='multinomial',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'C': [100, 1000], 'tol': [0.001, 0.0001]},
#              pre_dispatch='2*n_jobs', refit='True', return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print("best params: " + str(clf.best_params_))
# Out:
# best params: {'C': 1000, 'tol': 0.001}

# %%
test = pd.read_csv('test.csv')
test_ids = test.pop('id')
x_test = test.values
x_test = scaler.transform(x_test)
test.head()
# Out:
#     margin1   margin2   margin3  ...  texture62  texture63  texture64
# 0  0.019531  0.009766  0.078125  ...   0.000000   0.003906   0.053711
# 1  0.007812  0.005859  0.064453  ...   0.000977   0.037109   0.044922
# 2  0.000000  0.000000  0.001953  ...   0.015625   0.000000   0.000000
# 3  0.000000  0.000000  0.009766  ...   0.089844   0.000000   0.008789
# 4  0.001953  0.000000  0.015625  ...   0.007812   0.009766   0.007812
#
# [5 rows x 192 columns]

# %%
y_test = clf.predict_proba(x_test)
result = pd.DataFrame(y_test, index=test_ids, columns=le.classes_)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from statistics import *
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(log_reg, x_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1)
# report the model performance
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), stdev(n_scores)))
# Out:
# Mean Accuracy: 0.988 (0.014)

# %% [markdown]
# ## **OTHER EXAMPLE - GLASS PREDICTION**

# %%
link = "https://raw.githubusercontent.com/saimadhu-polamuri/DataAspirant_codes/master/Multinomial_Logistic_regression/Inputs/glass.txt"
header = ["Id", "RI", "Na", "Mg", "Al", "Si", "K", "Ca", "Ba", "Fe", "glass-type"]

df = pd.read_csv(link,names=header)
print("Number of observations :: ", len(df.index))
print("Number of columns :: ", len(df.columns))
print("Headers :: ", df.columns.values)
# Out:
# Number of observations ::  214
# Number of columns ::  11
# Headers ::  ['Id' 'RI' 'Na' 'Mg' 'Al' 'Si' 'K' 'Ca' 'Ba' 'Fe' 'glass-type']

# %%
train_x, test_x, train_y, test_y = train_test_split(df[header[:-1]], df[header[-1]], train_size=0.7)

# %%
lr = LogisticRegression(multi_class='multinomial', solver='newton-cg').fit(train_x, train_y)

# %%
from sklearn import metrics
print("Logistic regression Train Accuracy :: ", metrics.accuracy_score(train_y, lr.predict(train_x)))
print("Logistic regression Test Accuracy :: ", metrics.accuracy_score(test_y, lr.predict(test_x)))
print("Multinomial Logistic regression Train Accuracy :: ", metrics.accuracy_score(train_y, lr.predict(train_x)))
print("Multinomial Logistic regression Test Accuracy :: ", metrics.accuracy_score(test_y, lr.predict(test_x)))
# Out:
# Logistic regression Train Accuracy ::  1.0
# Logistic regression Test Accuracy ::  1.0
# Multinomial Logistic regression Train Accuracy ::  1.0
# Multinomial Logistic regression Test Accuracy ::  1.0
